# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/market_basket_optimisation.csv")
data.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 1            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 2            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 3            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 4            NaN       NaN   NaN   NaN           NaN    NaN               NaN
#
#   frozen smoothie spinach  olive oil
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN

# %%
data.shape
# Out:
# (7500, 20)

# %%
dataset.shape[0]
# Out:
# 7500

# %%
transaction = []
for i in range(0, data.shape[0]):
    for j in range(0, data.shape[1]):
        transaction.append(data.values[i,j])
# converting to numpy array
transaction = np.array(transaction)
#  Transform Them a Pandas DataFrame
df = pd.DataFrame(transaction, columns=["items"]) 
# Put 1 to Each Item For Making Countable Table, to be able to perform Group By
df["incident_count"] = 1 
#  Delete NaN Items from Dataset
indexNames = df[df['items'] == "nan" ].index
df.drop(indexNames , inplace=True)
# Making a New Appropriate Pandas DataFrame for Visualizations  
df_table = df.groupby("items").sum().sort_values("incident_count", ascending=False).reset_index()
#  Initial Visualizations
df_table.head(10).style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_a2194_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a2194_row1_col1 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_a2194_row2_col1 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_a2194_row3_col1 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_a2194_row4_col1 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_a2194_row5_col1 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_a2194_row6_col1 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_a2194_row7_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_a2194_row8_col1, #T_a2194_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_a2194">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2194_level0_col0" class="col_heading level0 col0" >items</th>
#       <th id="T_a2194_level0_col1" class="col_heading level0 col1" >incident_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2194_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2194_row0_col0" class="data row0 col0" >mineral water</td>
#       <td id="T_a2194_row0_col1" class="data row0 col1" >1787</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2194_row1_col0" class="data row1 col0" >eggs</td>
#       <td id="T_a2194_row1_col1" class="data row1 col1" >1348</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a2194_row2_col0" class="data row2 col0" >spaghetti</td>
#       <td id="T_a2194_row2_col1" class="data row2 col1" >1306</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a2194_row3_col0" class="data row3 col0" >french fries</td>
#       <td id="T_a2194_row3_col1" class="data row3 col1" >1282</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a2194_row4_col0" class="data row4 col0" >chocolate</td>
#       <td id="T_a2194_row4_col1" class="data row4 col1" >1230</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a2194_row5_col0" class="data row5 col0" >green tea</td>
#       <td id="T_a2194_row5_col1" class="data row5 col1" >990</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a2194_row6_col0" class="data row6 col0" >milk</td>
#       <td id="T_a2194_row6_col1" class="data row6 col1" >972</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a2194_row7_col0" class="data row7 col0" >ground beef</td>
#       <td id="T_a2194_row7_col1" class="data row7 col1" >737</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a2194_row8_col0" class="data row8 col0" >frozen vegetables</td>
#       <td id="T_a2194_row8_col1" class="data row8 col1" >715</td>
#     </tr>
#     <tr>
#       <th id="T_a2194_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a2194_row9_col0" class="data row9 col0" >pancakes</td>
#       <td id="T_a2194_row9_col1" class="data row9 col1" >713</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Data pre-processing

# %%
# importing the required module
from mlxtend.preprocessing import TransactionEncoder
# initializing the transactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transaction).transform(transaction)
dataset = pd.DataFrame(te_ary, columns=te.columns_)
# dataset after encoded
dataset
# Out:
#    False  True
# 0   True  True
# 1   True  True
# 2   True  True
# 3   True  True
# 4   True  True

# %% [markdown]
# # Using Apriori algorithm

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Extracting the most frequest itemsets via Mlxtend.
# The length column has been added to increase ease of filtering.
frequent_itemsets = apriori(dataset, min_support=0.01, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
# printing the frequent itemset
frequent_itemsets
# Out:
#        support                        itemsets  length
# 0     0.091747                             ( )       1
# 1     0.916693                             (a)       1
# 2     0.033720                             (b)       1
# 3     0.069000                             (c)       1
# 4     0.022027                             (d)       1
# ...        ...                             ...     ...
# 2182  0.011913     (r, m,  , w, t, a, l, n, e)       9
# 2183  0.011913     (i, r, m,  , w, t, a, l, n)       9
# 2184  0.011913     (i, r, m,  , w, t, l, n, e)       9
# 2185  0.011913     (i, r, m, w, t, a, l, n, e)       9
# 2186  0.011913  (i, r, m,  , w, t, a, l, n, e)      10
#
# [2187 rows x 3 columns]

# %%
# printing the frequntly items 
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.05) ]
# Out:
#       support itemsets  length
# 23   0.059573   ( , a)       2
# 27   0.080373   ( , e)       2
# 34   0.056340   ( , n)       2
# 36   0.072653   ( , r)       2
# 38   0.056087   ( , t)       2
# 45   0.093927   (a, e)       2
# 51   0.052973   (a, l)       2
# 53   0.849033   (a, n)       2
# 56   0.052827   (a, r)       2
# 57   0.055747   (s, a)       2
# 58   0.075867   (t, a)       2
# 71   0.061507   (c, e)       2
# 91   0.055373   (e, g)       2
# 92   0.058727   (e, h)       2
# 93   0.062980   (i, e)       2
# 97   0.069247   (n, e)       2
# 98   0.057233   (o, e)       2
# 100  0.084000   (r, e)       2
# 101  0.079233   (s, e)       2
# 102  0.077747   (t, e)       2
# 162  0.053927   (n, r)       2

# %%
# printing the frequntly items with length 3
frequent_itemsets[ (frequent_itemsets['length'] == 3) ].head(3)
# Out:
#       support   itemsets  length
# 186  0.015680  ( , a, b)       3
# 187  0.017833  ( , a, c)       3
# 188  0.052373  ( , a, e)       3

# %% [markdown]
# # Mining association rules

# %%
#  We set our metric as "Lift" to define whether antecedents & consequents are dependent our not
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)
rules["antecedents_length"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_length"] = rules["consequents"].apply(lambda x: len(x))
rules.sort_values("lift",ascending=False)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric, antecedents_length, consequents_length]
# Index: []

# %% [markdown]
# **Confidence**

# %%
# Sort values based on confidence
rules.sort_values("confidence",ascending=False)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric, antecedents_length, consequents_length]
# Index: []
